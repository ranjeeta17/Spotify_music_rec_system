# %% [markdown]
# #LIBRARIES

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %% [markdown]
# #Mount_Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Load_Dataset

# %%
data = pd.read_csv("/content/drive/MyDrive/ML_Project/spotify.csv")

# %% [markdown]
# #print initial 5 records

# %%
data.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# ...

# %% [markdown]
# #No of Records And Features

# %%
data.shape
# Out:
# (174389, 19)

# %% [markdown]
# #Data Exploration..

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174389 entries, 0 to 174388
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      174389 non-null  float64
#  1   artists           174389 non-null  object
#  2   danceability      174389 non-null  float64
#  3   duration_ms       174389 non-null  int64
#  4   energy            174389 non-null  float64
#  5   explicit          174389 non-null  int64
#  6   id                174389 non-null  object
#  7   instrumentalness  174389 non-null  float64
#  8   key               174389 non-null  int64
#  9   liveness          174389 non-null  float64
#  10  loudness          174389 non-null  float64
#  11  mode              174389 non-null  int64
#  12  name              174389 non-null  object
#  13  popularity        174389 non-null  int64
#  14  release_date      174389 non-null  object
#  15  speechiness       174389 non-null  float64
# ...

# %% [markdown]
# #DATA VISUALIZATION

# %%
data.hist(figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f379c12fd00>,
# ...
#       dtype=object)

# %%
data.isnull().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %% [markdown]
# #Data Transformation

# %%
from sklearn.preprocessing import MinMaxScaler
# datatypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
# data = data.select_dtypes(include=datatypes)
for col in data.columns:
    MinMaxScaler(col)

# %% [markdown]
# #After Standardization

# %%
data
# Out:
#         acousticness                             artists  danceability  \
# 0           0.991000                     ['Mamie Smith']         0.598
# 1           0.643000           ["Screamin' Jay Hawkins"]         0.852
# 2           0.993000                     ['Mamie Smith']         0.647
# 3           0.000173                 ['Oscar Velazquez']         0.730
# 4           0.295000                            ['Mixe']         0.704
# ...              ...                                 ...           ...
# 174384      0.009170  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 174385      0.795000                    ['Alessia Cara']         0.429
# 174386      0.806000                       ['Roger Fly']         0.671
# 174387      0.920000                    ['Taylor Swift']         0.462
# 174388      0.239000                       ['Roger Fly']         0.677
#
#         duration_ms  energy  explicit                      id  \
# ...

# %% [markdown]
# #Drop the feature.

# %%
data_copy = data.copy()
df = data_copy.drop(columns=['id', 'name', 'artists', 'release_date', 'year'])
df.corr()
# Out:
#                   acousticness  danceability  duration_ms    energy  explicit  \
# acousticness          1.000000     -0.263217    -0.089169 -0.750852 -0.208176
# danceability         -0.263217      1.000000    -0.100757  0.204838  0.200842
# duration_ms          -0.089169     -0.100757     1.000000  0.060516 -0.033808
# energy               -0.750852      0.204838     0.060516  1.000000  0.102561
# explicit             -0.208176      0.200842    -0.033808  0.102561  1.000000
# instrumentalness      0.221956     -0.215589     0.103621 -0.177750 -0.130609
# key                  -0.028028      0.026266     0.002020  0.035780  0.005282
# liveness             -0.029654     -0.110033     0.028942  0.134815  0.037288
# loudness             -0.546639      0.249541     0.019791  0.779267  0.106249
# mode                  0.064633     -0.048358    -0.046849 -0.056160 -0.062503
# popularity           -0.396744      0.123746     0.024717  0.328939  0.152545
# ...

# %% [markdown]
# #**Correlation Matrix**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Increase the size of the heatmap.
plt.figure(figsize=(12, 6))
# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# #Songs of different genres may have similar characteristics which may affect the recommendation system. So I’m going to create a new feature here that will differentiate songs from different categories. For this task, I’ll use the K means clustering algorithm

# %% [markdown]
# #**Kmeans Clusstering**

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=10)
features = kmeans.fit_predict(df)
data['features'] = features
MinMaxScaler(data['features'])
# Out:
# MinMaxScaler(feature_range=0         0
# 1         0
# 2         0
# 3         9
# 4         0
#          ..
# 174384    0
# 174385    0
# 174386    6
# 174387    6
# 174388    6
# Name: features, Length: 174389, dtype: int32)

# %%
data.shape
# Out:
# (174389, 20)

# %%
data
# Out:
#         acousticness                             artists  danceability  \
# 0           0.991000                     ['Mamie Smith']         0.598
# 1           0.643000           ["Screamin' Jay Hawkins"]         0.852
# 2           0.993000                     ['Mamie Smith']         0.647
# 3           0.000173                 ['Oscar Velazquez']         0.730
# 4           0.295000                            ['Mixe']         0.704
# ...              ...                                 ...           ...
# 174384      0.009170  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 174385      0.795000                    ['Alessia Cara']         0.429
# 174386      0.806000                       ['Roger Fly']         0.671
# 174387      0.920000                    ['Taylor Swift']         0.462
# 174388      0.239000                       ['Roger Fly']         0.677
#
#         duration_ms  energy  explicit                      id  \
# ...

# %%
distortions = []
for i in range(1, 11):
    km = KMeans(n_clusters=i)
    km.fit(df)
    distortions.append(km.inertia_)
plt.plot(range(1, 11), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.tight_layout()
#plt.savefig('images/11_03.png', dpi=300)
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)
features = kmeans.fit_predict(df)
data['features'] = features
MinMaxScaler(data['features'])
# Out:
# MinMaxScaler(feature_range=0         0
# 1         0
# 2         0
# 3         2
# 4         0
#          ..
# 174384    0
# 174385    0
# 174386    3
# 174387    3
# 174388    0
# Name: features, Length: 174389, dtype: int32)

# %%
kmeans.inertia_
# Out:
# 538269409032470.6

# %% [markdown]
# #CREATING A CLASS TO RECOMMEND THE SONGS

# %%
class Spotify_Recommendation():
    def __init__(self, dataset):
        self.dataset = dataset
    def recommend(self, songs, amount=1):
        distance = []
        song = self.dataset[(self.dataset.name.str.lower() == songs.lower())].head(1).values[0]
        rec = self.dataset[self.dataset.name.str.lower() != songs.lower()]
        for songs in tqdm(rec.values):
            d = 0
            for col in np.arange(len(rec.columns)):
                if not col in [1, 6, 12, 14, 18]:
                    d = d + np.absolute(float(song[col]) - float(songs[col]))
            distance.append(d)
        rec['distance'] = distance
        rec = rec.sort_values('distance')
        columns = ['artists', 'name']
        return rec[columns][:amount]

recommendations = Spotify_Recommendation(data)
recommendations.recommend("Dust", 10)
# Out:
# 100%|██████████| 174384/174384 [00:10<00:00, 17189.91it/s]
# <ipython-input-20-1ef0c2790dfa>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec['distance'] = distance
#                                                   artists  \
# 60779   ['Giorgos Papasideris', 'Antonis Lavidas-klari...
# 111213  ['Giorgos Papasideris', 'Antonis Lavidas', 'Kl...
# 111255  ['Giorgos Papasideris', 'Klarino-Antonis Lavid...
# 2002        ['Petros Epitropakis', 'Antonis Kalampousis']
# 21490                               ['Markos Vamvakaris']
# 23066                    ['Leadbelly with Sarah Garland']
# 24525                                    ['Woody Herman']
# 59882                                       ['Liva Weel']
# ...

# %% [markdown]
# #**kMeans++**

# %%
from sklearn.cluster import KMeans
kmpp = KMeans(n_clusters=10, 
            init='k-means++', 
            n_init=10, 
            max_iter=300,
            tol=1e-04,
            random_state=0)

y_km = kmpp.fit_predict(df)
data['features'] = y_km
MinMaxScaler(data['features'])
# Out:
# MinMaxScaler(feature_range=0         3
# 1         3
# 2         3
# 3         9
# 4         3
#          ..
# 174384    3
# 174385    3
# 174386    0
# 174387    0
# 174388    0
# Name: features, Length: 174389, dtype: int32)

# %%
distortions = []
for i in range(1, 11):
    km = KMeans(n_clusters=i, 
                init='k-means++', 
                n_init=10, 
                max_iter=300, 
                random_state=0)
    km.fit(df)
    distortions.append(km.inertia_)
plt.plot(range(1, 11), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.tight_layout()
plt.show()

# %%
from sklearn.cluster import KMeans

kmpp = KMeans(n_clusters=5, 
            init='k-means++', 
            n_init=10, 
            max_iter=300,
            tol=1e-04,
            random_state=0)

y_km = kmpp.fit_predict(df)
data['features'] = y_km
MinMaxScaler(data['features'])
# Out:
# MinMaxScaler(feature_range=0         1
# 1         1
# 2         1
# 3         0
# 4         1
#          ..
# 174384    1
# 174385    1
# 174386    4
# 174387    4
# 174388    1
# Name: features, Length: 174389, dtype: int32)

# %%
kmpp.inertia_
# Out:
# 538271161874780.75

# %%
data['name'] = data['name'].str.lower()

# %%
data.shape
# Out:
# (174389, 20)

# %%
data.to_csv(r'/content/drive/MyDrive/dataset.csv')

# %%
class Spotify_Recommendation():
    def __init__(self, dataset):
        self.dataset = dataset
    def recommend(self, songs, amount=1):
        distance = []
        song = self.dataset[(self.dataset.name.str.lower() == songs.lower())].head(1).values[0]
        rec = self.dataset[self.dataset.name.str.lower() != songs.lower()]
        for s in tqdm(rec.values):
            d = 0
            for col in np.arange(len(rec.columns)):
                if not col in [1, 6, 12, 14, 18]:
                    d = d + np.absolute(float(song[col]) - float(s[col]))
            distance.append(d)
        rec['distance'] = distance
        rec = rec.sort_values('distance')
        columns = ['artists', 'name']
        return rec[columns][:amount]

recommendations = Spotify_Recommendation(data)
name = "Dust"
name= name.lower()
recommendations.recommend(name, 10)
# Out:
# 100%|██████████| 174384/174384 [00:10<00:00, 17094.77it/s]
# <ipython-input-20-dfce9c31e78b>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec['distance'] = distance
#                                                   artists  \
# 60779   ['Giorgos Papasideris', 'Antonis Lavidas-klari...
# 111213  ['Giorgos Papasideris', 'Antonis Lavidas', 'Kl...
# 111255  ['Giorgos Papasideris', 'Klarino-Antonis Lavid...
# 2002        ['Petros Epitropakis', 'Antonis Kalampousis']
# 21490                               ['Markos Vamvakaris']
# 23066                    ['Leadbelly with Sarah Garland']
# 24525                                    ['Woody Herman']
# 59882                                       ['Liva Weel']
# ...

# %% [markdown]
# #**DBSCAN**

# %%
from sklearn.cluster import DBSCAN
db = DBSCAN(eps=0.3, min_samples=10).fit(df)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# %%
labels_true= df.columns.values

# %%
df_1 = df.copy()
df_2 = df_1.iloc[0:10000:,:]

# %%
df_2
# Out:
#       acousticness  danceability  duration_ms  energy  explicit  \
# 0         0.991000         0.598       168333   0.224         0
# 1         0.643000         0.852       150200   0.517         0
# 2         0.993000         0.647       163827   0.186         0
# 3         0.000173         0.730       422087   0.798         0
# 4         0.295000         0.704       165224   0.707         1
# ...            ...           ...          ...     ...       ...
# 9995      0.001520         0.424       372145   0.662         0
# 9996      0.158000         0.774       176704   0.580         0
# 9997      0.156000         0.581       199293   0.806         0
# 9998      0.528000         0.647       284640   0.596         0
# 9999      0.464000         0.445       217747   0.444         0
#
#       instrumentalness  key  liveness  loudness  mode  popularity  \
# 0             0.000522    5    0.3790   -12.628     0          12
# ...

# %% [markdown]
# #**Herarchial clustring**

# %%
from scipy.cluster.hierarchy import linkage
row_clusters = linkage(df_2.values, method='complete', metric='euclidean')

# %%
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

# %%
dataset = data
songs = "Dust"
song = dataset[(dataset.name.str.lower() == songs.lower())].values[0]
rec =  dataset[dataset.name.str.lower() != songs.lower()]
song
# Out:
# array([0.989, "['The Columbia Photo Players']", 0.759, 191827, 0.34, 0,
#        '07Hbp0v6qpkMfNmNPpsz6X', 0.0721, 5, 0.0734, -11.025, 1, 'Dust', 3,
#        '1925', 0.0801, 102.731, 0.8909999999999999, 1925, 3], dtype=object)

# %%
class Spotify_Recommendation():
    def __init__(self, dataset):
        self.dataset = dataset
    def recommend(self, songs, amount=1):
        distance = []
        song = self.dataset[(self.dataset.name.str.lower() == songs.lower())].head(1).values[0]
        rec = self.dataset[self.dataset.name.str.lower() != songs.lower()]
        for songs in tqdm(rec.values):
            d = 0
            for col in np.arange(len(rec.columns)):
                if not col in [1, 6, 12, 14, 18]:
                    d = d + np.absolute(float(song[col]) - float(songs[col]))
            distance.append(d)
        rec['distance'] = distance
        rec = rec.sort_values('distance')
        columns = ['artists', 'name']
        return rec[columns][:amount]

recommendations = Spotify_Recommendation(data)
recommendations.recommend("Dust", 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-2a8f2b80c39e> in <module>
#       1 d = 0
# ----> 2 for col in np.arange(len(rec.columns)):
#       3     if not col in [1, 6, 12, 14, 18]:
#       4       print(song[col])
#       5
#
# NameError: name 'rec' is not defined
